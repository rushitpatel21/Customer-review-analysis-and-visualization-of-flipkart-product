# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

# %%
df = pd.read_csv('./FlipkartReview.csv')

# %%
def handleDate(data):
    if 'ago' in data:
        return np.nan
    else:
        return data
    
df['Date'] = df['Date'].apply(handleDate)

# %%
def handleDesc(data):
    if 'READ MORE' in data:
        return data.replace('READ MORE','')
    else:
        return data
    
df['Desc'] = df['Desc'].apply(handleDesc)

# %%
graph1 = pd.DataFrame({'Star':df['Star'],'Date':df['Date']})
graph1
# Out:
#      Star       Date
# 0       5  Nov, 2020
# 1       5  Aug, 2020
# 2       4  Jun, 2021
# 3       4  Aug, 2020
# 4       3  Aug, 2020
# ..    ...        ...
# 97      4  Aug, 2020
# 98      5  Aug, 2020
# 99      4  Aug, 2020
# 100     5  Aug, 2020
# 101     5  Aug, 2020
#
# [102 rows x 2 columns]

# %%
sns.lineplot(x='Star',y='Date',data=graph1)
# Out:
# <Axes: xlabel='Star', ylabel='Date'>
